# %%
from selenium import webdriver

# %%
import webbrowser

# %%
import os

# %%
from bs4 import BeautifulSoup

# %%
import urllib

# %%
import re

# %%
from urllib.request import urlopen

# %%
driver = webdriver.Chrome('C:\\Users\\mjkim\\PythonCode\\chromedriver')

# %%
driver.implicitly_wait(3)

# %%
url='http://www.gevolution.co.kr/rank/ios.asp'

# %%
driver.get(url)

# %%
soup=BeautifulSoup(driver.page_source,'lxml')

# %%
soup.select('.item-info img')
# Out:
# [<img alt="" height="50" original="https://lh3.googleusercontent.com/P0dnnTBwMPQAf3kmXriZ7lcrr2YHIkPUpjCARmY9HVB09jp86OMxwIlcBXhyRYrX0Q=w50" src="https://lh3.googleusercontent.com/P0dnnTBwMPQAf3kmXriZ7lcrr2YHIkPUpjCARmY9HVB09jp86OMxwIlcBXhyRYrX0Q=w50" width="50"/>,
#  <img alt="" height="50" original="https://lh3.googleusercontent.com/LaB4TOmkizqBWqy0Vy8lw01JBiBxcW-ifMm_q3GIZ_JOCPKSLarmMjqWClBcILVtMmI=w50" src="https://lh3.googleusercontent.com/LaB4TOmkizqBWqy0Vy8lw01JBiBxcW-ifMm_q3GIZ_JOCPKSLarmMjqWClBcILVtMmI=w50" width="50"/>,
#  <img alt="" height="50" original="https://lh3.googleusercontent.com/-3TMAG8SIXQ9cTlbZMHHbxeYfFwcqFyi5DjMEMmQdRSHduYYNnkuQ7RrTfEYzVrkG2I=w50" src="https://lh3.googleusercontent.com/-3TMAG8SIXQ9cTlbZMHHbxeYfFwcqFyi5DjMEMmQdRSHduYYNnkuQ7RrTfEYzVrkG2I=w50" width="50"/>,
#  <img alt="" height="50" original="https://lh3.googleusercontent.com/rPvgLje5dh9bInqtoXGlmAp9DMNCaiAVQLEGthsTQKLSOa5GKoIIJC0Nc_e5ZDovTg=w50" width="50"/>,
# ...

# %%
img=list()

# %%
img2=list()

# %%
img3=list()

# %%
#imgparse=list()

# %%
for e in soup.select('.item-info img'):
    img.append(str(e))

# %%
img
# Out:
# ['<img alt="" height="50" original="https://lh3.googleusercontent.com/P0dnnTBwMPQAf3kmXriZ7lcrr2YHIkPUpjCARmY9HVB09jp86OMxwIlcBXhyRYrX0Q=w50" src="https://lh3.googleusercontent.com/P0dnnTBwMPQAf3kmXriZ7lcrr2YHIkPUpjCARmY9HVB09jp86OMxwIlcBXhyRYrX0Q=w50" width="50"/>',
#  '<img alt="" height="50" original="https://lh3.googleusercontent.com/LaB4TOmkizqBWqy0Vy8lw01JBiBxcW-ifMm_q3GIZ_JOCPKSLarmMjqWClBcILVtMmI=w50" src="https://lh3.googleusercontent.com/LaB4TOmkizqBWqy0Vy8lw01JBiBxcW-ifMm_q3GIZ_JOCPKSLarmMjqWClBcILVtMmI=w50" width="50"/>',
#  '<img alt="" height="50" original="https://lh3.googleusercontent.com/-3TMAG8SIXQ9cTlbZMHHbxeYfFwcqFyi5DjMEMmQdRSHduYYNnkuQ7RrTfEYzVrkG2I=w50" src="https://lh3.googleusercontent.com/-3TMAG8SIXQ9cTlbZMHHbxeYfFwcqFyi5DjMEMmQdRSHduYYNnkuQ7RrTfEYzVrkG2I=w50" width="50"/>',
#  '<img alt="" height="50" original="https://lh3.googleusercontent.com/rPvgLje5dh9bInqtoXGlmAp9DMNCaiAVQLEGthsTQKLSOa5GKoIIJC0Nc_e5ZDovTg=w50" width="50"/>',
# ...

# %%
for e in img:
    img2.append(e.replace('<img alt="" height="50" original="',''))

# %%
img2
# Out:
# ['https://lh3.googleusercontent.com/P0dnnTBwMPQAf3kmXriZ7lcrr2YHIkPUpjCARmY9HVB09jp86OMxwIlcBXhyRYrX0Q=w50" src="https://lh3.googleusercontent.com/P0dnnTBwMPQAf3kmXriZ7lcrr2YHIkPUpjCARmY9HVB09jp86OMxwIlcBXhyRYrX0Q=w50" width="50"/>',
#  'https://lh3.googleusercontent.com/LaB4TOmkizqBWqy0Vy8lw01JBiBxcW-ifMm_q3GIZ_JOCPKSLarmMjqWClBcILVtMmI=w50" src="https://lh3.googleusercontent.com/LaB4TOmkizqBWqy0Vy8lw01JBiBxcW-ifMm_q3GIZ_JOCPKSLarmMjqWClBcILVtMmI=w50" width="50"/>',
#  'https://lh3.googleusercontent.com/-3TMAG8SIXQ9cTlbZMHHbxeYfFwcqFyi5DjMEMmQdRSHduYYNnkuQ7RrTfEYzVrkG2I=w50" src="https://lh3.googleusercontent.com/-3TMAG8SIXQ9cTlbZMHHbxeYfFwcqFyi5DjMEMmQdRSHduYYNnkuQ7RrTfEYzVrkG2I=w50" width="50"/>',
#  'https://lh3.googleusercontent.com/rPvgLje5dh9bInqtoXGlmAp9DMNCaiAVQLEGthsTQKLSOa5GKoIIJC0Nc_e5ZDovTg=w50" width="50"/>',
#  'http://upload.gevolution.co.kr/appicon/s0553000/gevolution_00552611_icon_50.png" width="50"/>',
# ...

# %%
for e in img2:
    img3.append(e.replace('" width="50"/>',""))

# %%
img3
# Out:
# ['https://lh3.googleusercontent.com/P0dnnTBwMPQAf3kmXriZ7lcrr2YHIkPUpjCARmY9HVB09jp86OMxwIlcBXhyRYrX0Q=w50" src="https://lh3.googleusercontent.com/P0dnnTBwMPQAf3kmXriZ7lcrr2YHIkPUpjCARmY9HVB09jp86OMxwIlcBXhyRYrX0Q=w50',
#  'https://lh3.googleusercontent.com/LaB4TOmkizqBWqy0Vy8lw01JBiBxcW-ifMm_q3GIZ_JOCPKSLarmMjqWClBcILVtMmI=w50" src="https://lh3.googleusercontent.com/LaB4TOmkizqBWqy0Vy8lw01JBiBxcW-ifMm_q3GIZ_JOCPKSLarmMjqWClBcILVtMmI=w50',
#  'https://lh3.googleusercontent.com/-3TMAG8SIXQ9cTlbZMHHbxeYfFwcqFyi5DjMEMmQdRSHduYYNnkuQ7RrTfEYzVrkG2I=w50" src="https://lh3.googleusercontent.com/-3TMAG8SIXQ9cTlbZMHHbxeYfFwcqFyi5DjMEMmQdRSHduYYNnkuQ7RrTfEYzVrkG2I=w50',
#  'https://lh3.googleusercontent.com/rPvgLje5dh9bInqtoXGlmAp9DMNCaiAVQLEGthsTQKLSOa5GKoIIJC0Nc_e5ZDovTg=w50',
#  'http://upload.gevolution.co.kr/appicon/s0553000/gevolution_00552611_icon_50.png',
#  'https://lh3.googleusercontent.com/D8Cv42dxKkXaqsX4Y54QQZDAO12QRhQReUVmU9qWAKSYK9QMD33rrYQogww_SRsyoKE=w50',
# ...

# %%
len(img3)
# Out:
# 300

# %%
urlfree=list()

# %%
urlpay=list()

# %%
urlincome=list()

# %%
for e in range(300):
    if e%3==0:
        urlfree.append(img3[e])
    elif e%3==1:
        urlpay.append(img3[e])
    elif e%3==2:
        urlincome.append(img3[e])

# %%
urlfree
# Out:
# ['https://lh3.googleusercontent.com/P0dnnTBwMPQAf3kmXriZ7lcrr2YHIkPUpjCARmY9HVB09jp86OMxwIlcBXhyRYrX0Q=w50" src="https://lh3.googleusercontent.com/P0dnnTBwMPQAf3kmXriZ7lcrr2YHIkPUpjCARmY9HVB09jp86OMxwIlcBXhyRYrX0Q=w50',
#  'https://lh3.googleusercontent.com/rPvgLje5dh9bInqtoXGlmAp9DMNCaiAVQLEGthsTQKLSOa5GKoIIJC0Nc_e5ZDovTg=w50',
#  'https://lh3.googleusercontent.com/Y2kNEWlFihHF76bgMW4KFearXH_RhHAmnbmiYhiPpq_btK9dvOtizxb89Vu25Dk-Vw=w50',
#  'https://lh3.googleusercontent.com/yiGs7u7kCVyRQ18fRdkObMIZ1zIVrekZ5ZqqGCM5VEFaJxy7Je2xp_MDYz8pjdSIuA=w50',
#  'https://lh3.googleusercontent.com/lJeizsupizjiiOdqogoaPhS5PuNo9zhrNGjfbgLbuwIAlq3NC4paVXLOc3ykZ8XKxro=w50',
#  'https://lh3.googleusercontent.com/xhh3ehN9RaCn_bT2t0SXJmFCSdMS9r3IArsSkNneb9xJs_VG06jpczEupaCy-hVsbuQ=w50',
#  'http://upload.gevolution.co.kr/appicon/s0538000/gevolution_00538419_icon_50.png',
#  'http://upload.gevolution.co.kr/appicon/s0611000/gevolution_00610855_icon_50.png',
# ...

# %%
urlpay
# Out:
# ['https://lh3.googleusercontent.com/LaB4TOmkizqBWqy0Vy8lw01JBiBxcW-ifMm_q3GIZ_JOCPKSLarmMjqWClBcILVtMmI=w50" src="https://lh3.googleusercontent.com/LaB4TOmkizqBWqy0Vy8lw01JBiBxcW-ifMm_q3GIZ_JOCPKSLarmMjqWClBcILVtMmI=w50',
#  'http://upload.gevolution.co.kr/appicon/s0553000/gevolution_00552611_icon_50.png',
#  'https://lh3.googleusercontent.com/VSwHQjcAttxsLE47RuS4PqpC4LT7lCoSjE7Hx5AW_yCxtDvcnsHHvm5CTuL5BPN-uRTP=w50',
#  'https://lh3.googleusercontent.com/YMm_2EMqth0d0Je_s_IowVTO7GI5kVj0r0mj4fD2VekFcArcthfzhN3Bf64FXzzdA8M=w50',
#  'https://lh3.googleusercontent.com/KOaV4GlkzFbp0UKop97mKmzlKwqOCzlrcvW3nSFmAU-5-RIlO7yM9RMTcoYTnAptAqBk=w50',
#  'https://lh3.googleusercontent.com/cWl4eOFUszh0muXX8dXmmhW0sf-DJj-DvHAeL3mfywYJodXW-VUoFJVdmKER585a3d0=w50',
#  'https://lh3.googleusercontent.com/hm-DgQ7P7vic-uU7Qs0VzlOgmtbT4vxSRdsQEJpeu2QAMvAWNIuH2tNnSjPNfviMDw=w50',
# ...

# %%
urlincome
# Out:
# ['https://lh3.googleusercontent.com/-3TMAG8SIXQ9cTlbZMHHbxeYfFwcqFyi5DjMEMmQdRSHduYYNnkuQ7RrTfEYzVrkG2I=w50" src="https://lh3.googleusercontent.com/-3TMAG8SIXQ9cTlbZMHHbxeYfFwcqFyi5DjMEMmQdRSHduYYNnkuQ7RrTfEYzVrkG2I=w50',
#  'https://lh3.googleusercontent.com/D8Cv42dxKkXaqsX4Y54QQZDAO12QRhQReUVmU9qWAKSYK9QMD33rrYQogww_SRsyoKE=w50',
#  'https://lh3.googleusercontent.com/57uWdRGreUejc5-8nlOgtv_JX4ykjy9JojlCQcNRz6hFUWHVMUEZCwuzfK3p2WIPSKQ=w50',
#  'https://lh3.googleusercontent.com/ELgpMCOie0382Qij3US_NAgTmfOZO7Sz8CwIw2YjDgsnXbr9kUocV-k1Sao953mYCG0=w50',
#  'https://lh3.googleusercontent.com/ZVCQrF-OKn3gwokEi7E86LXvchAqL6wFx4fEj5oLRpPlJIJ1a0WVgqJ0vfCjEGdgFw=w50',
#  'https://lh3.googleusercontent.com/9Ox11VoydjIjG2N5b-vW-IELHTuJXsHumGBSysNt0lUy-OXmc5WYX9BP1PSzSihNx-U=w50',
#  'https://lh3.googleusercontent.com/K6A_2LT_gKqq0eTRytF9OP1O_9OI-mlNZDw_7k12QWwf4LLgYegnVWH-XsL7gm2kCmg=w50',
# ...

# %%
urlfree2=list()
urlpay2=list()
urlincome2=list()

# %%
for e in urlfree:
    urlfree2.append(e+'\n')

# %%
for e in urlpay:

    urlpay2.append(e+'\n')

# %%
for e in urlincome:
    urlincome2.append(e+'\n')

# %%
urlfree2
# Out:
# ['https://lh3.googleusercontent.com/P0dnnTBwMPQAf3kmXriZ7lcrr2YHIkPUpjCARmY9HVB09jp86OMxwIlcBXhyRYrX0Q=w50" src="https://lh3.googleusercontent.com/P0dnnTBwMPQAf3kmXriZ7lcrr2YHIkPUpjCARmY9HVB09jp86OMxwIlcBXhyRYrX0Q=w50\n',
#  'https://lh3.googleusercontent.com/rPvgLje5dh9bInqtoXGlmAp9DMNCaiAVQLEGthsTQKLSOa5GKoIIJC0Nc_e5ZDovTg=w50\n',
#  'https://lh3.googleusercontent.com/Y2kNEWlFihHF76bgMW4KFearXH_RhHAmnbmiYhiPpq_btK9dvOtizxb89Vu25Dk-Vw=w50\n',
#  'https://lh3.googleusercontent.com/yiGs7u7kCVyRQ18fRdkObMIZ1zIVrekZ5ZqqGCM5VEFaJxy7Je2xp_MDYz8pjdSIuA=w50\n',
#  'https://lh3.googleusercontent.com/lJeizsupizjiiOdqogoaPhS5PuNo9zhrNGjfbgLbuwIAlq3NC4paVXLOc3ykZ8XKxro=w50\n',
#  'https://lh3.googleusercontent.com/xhh3ehN9RaCn_bT2t0SXJmFCSdMS9r3IArsSkNneb9xJs_VG06jpczEupaCy-hVsbuQ=w50\n',
#  'http://upload.gevolution.co.kr/appicon/s0538000/gevolution_00538419_icon_50.png\n',
#  'http://upload.gevolution.co.kr/appicon/s0611000/gevolution_00610855_icon_50.png\n',
# ...

# %%
f=open('free_img_a.txt',mode='wt',encoding='utf-8')

# %%
help(f)
# Out:
# Help on TextIOWrapper object:
#
# class TextIOWrapper(_TextIOBase)
#  |  TextIOWrapper(buffer, encoding=None, errors=None, newline=None, line_buffering=False, write_through=False)
#  |
#  |  Character and line based layer over a BufferedIOBase object, buffer.
#  |
#  |  encoding gives the name of the encoding that the stream will be
#  |  decoded or encoded with. It defaults to locale.getpreferredencoding(False).
#  |
#  |  errors determines the strictness of encoding and decoding (see
#  |  help(codecs.Codec) or the documentation for codecs.register) and
#  |  defaults to "strict".
#  |
#  |  newline controls how line endings are handled. It can be None, '',
#  |  '\n', '\r', and '\r\n'.  It works as follows:
#  |
#  |  * On input, if newline is None, universal newlines mode is
#  |    enabled. Lines in the input can end in '\n', '\r', or '\r\n', and
#  |    these are translated into '\n' before being returned to the
# ...

# %%
for e in urlfree2:
    f.write(e)

# %%
f=open('charged_img_a.txt',mode='wt',encoding='utf-8')

# %%
help(f)
# Out:
# Help on TextIOWrapper object:
#
# class TextIOWrapper(_TextIOBase)
#  |  TextIOWrapper(buffer, encoding=None, errors=None, newline=None, line_buffering=False, write_through=False)
#  |
#  |  Character and line based layer over a BufferedIOBase object, buffer.
#  |
#  |  encoding gives the name of the encoding that the stream will be
#  |  decoded or encoded with. It defaults to locale.getpreferredencoding(False).
#  |
#  |  errors determines the strictness of encoding and decoding (see
#  |  help(codecs.Codec) or the documentation for codecs.register) and
#  |  defaults to "strict".
#  |
#  |  newline controls how line endings are handled. It can be None, '',
#  |  '\n', '\r', and '\r\n'.  It works as follows:
#  |
#  |  * On input, if newline is None, universal newlines mode is
#  |    enabled. Lines in the input can end in '\n', '\r', or '\r\n', and
#  |    these are translated into '\n' before being returned to the
# ...

# %%
for e in urlpay2:
    f.write(e)

# %%
f=open('bestseller_img_a.txt',mode='wt',encoding='utf-8')
help(f)
for e in urlincome2:
    f.write(e)
# Out:
# Help on TextIOWrapper object:
#
# class TextIOWrapper(_TextIOBase)
#  |  TextIOWrapper(buffer, encoding=None, errors=None, newline=None, line_buffering=False, write_through=False)
#  |
#  |  Character and line based layer over a BufferedIOBase object, buffer.
#  |
#  |  encoding gives the name of the encoding that the stream will be
#  |  decoded or encoded with. It defaults to locale.getpreferredencoding(False).
#  |
#  |  errors determines the strictness of encoding and decoding (see
#  |  help(codecs.Codec) or the documentation for codecs.register) and
#  |  defaults to "strict".
#  |
#  |  newline controls how line endings are handled. It can be None, '',
#  |  '\n', '\r', and '\r\n'.  It works as follows:
#  |
#  |  * On input, if newline is None, universal newlines mode is
#  |    enabled. Lines in the input can end in '\n', '\r', or '\r\n', and
#  |    these are translated into '\n' before being returned to the
# ...

# %%
f.close()

# %%
# Out:
# []
